# %%
import pandas as pd
import numpy as np
import csv
import os

# %%
file = os.path.join ('data', 'vgsales.csv')
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.Year = df.Year.fillna(0.0).astype(int)

# %%
df = df.sort_values(by=['Year'], ascending=False)
df.head(10)
# Out:
#         Rank                                               Name Platform  \
# 5957    5959                             Imagine: Makeup Artist       DS
# 14390  14393   Phantasy Star Online 2 Episode 4: Deluxe Package      PS4
# 16438  16441                   Brothers Conflict: Precious Baby      PSV
# 16241  16244   Phantasy Star Online 2 Episode 4: Deluxe Package      PSV
# 7060    7062  Dragon Quest Heroes II: Twin Kings and the Pro...      PSV
# 15016  15019  TV Anime Idolm@ster: Cinderella Girls G4U! Pac...      PS3
# 6203    6205  Dragon Quest Heroes II: Twin Kings and the Pro...      PS4
# 16028  16031                                  Wand of Fortune R      PSV
# 6205    6207                                     UEFA Euro 2016      PS4
# 14738  14741                          Pro Evolution Soccer 2017     XOne
#
#        Year         Genre                     Publisher  NA_Sales  EU_Sales  \
# 5957   2020    Simulation                       Ubisoft      0.27      0.00
# 14390  2017  Role-Playing                          Sega      0.00      0.00
# 16438  2017        Action                  Idea Factory      0.00      0.00
# 16241  2017  Role-Playing                          Sega      0.00      0.00
# 7060   2016        Action                   Square Enix      0.00      0.00
# 15016  2016          Misc            Namco Bandai Games      0.00      0.00
# 6203   2016        Action                   Square Enix      0.00      0.00
# 16028  2016     Adventure                  Idea Factory      0.00      0.00
# 6205   2016        Sports  Konami Digital Entertainment      0.00      0.21
# 14738  2016        Sports  Konami Digital Entertainment      0.00      0.02
#
#        JP_Sales  Other_Sales  Global_Sales
# 5957       0.00         0.02          0.29
# 14390      0.03         0.00          0.03
# 16438      0.01         0.00          0.01
# 16241      0.01         0.00          0.01
# 7060       0.23         0.00          0.23
# 15016      0.02         0.00          0.02
# 6203       0.28         0.00          0.28
# 16028      0.01         0.00          0.01
# 6205       0.03         0.03          0.28
# 14738      0.00         0.00          0.03

# %%
df.sort_values(by=['Global_Sales'], ascending=False).head(1)
# Out:
#    Rank        Name Platform  Year   Genre Publisher  NA_Sales  EU_Sales  \
# 0     1  Wii Sports      Wii  2006  Sports  Nintendo     41.49     29.02
#
#    JP_Sales  Other_Sales  Global_Sales
# 0      3.77         8.46         82.74

# %%
df.sort_values(by=['JP_Sales'], ascending=False).head(1)
# Out:
#    Rank                      Name Platform  Year         Genre Publisher  \
# 4     5  Pokemon Red/Pokemon Blue       GB  1996  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 4     11.27      8.89     10.22          1.0         31.37
